# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing Visualization Libraries and Clean Data (from previous notebook)
# #### 3. Exploring Relationships
#      Correlations
#      Scatterplots
#      Pair Plots
#      Categorical Plots

# %% [markdown]
# ### task1 - Data and Vis libraries import

# %%
# Importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Checking matplotlib version (i ran the update and still 3.7 version comes up)
matplotlib.__version__
# Out:
# '3.7.1'

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.
# %matplotlib inline

# %%
# Path to the prepared data
path= r"/Users/mentaykoshzhanova/Desktop/project 6"
path
# Out:
# '/Users/mentaykoshzhanova/Desktop/project 6'

# %%
# Import data
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df.csv'), index_col = False)

# %%
df.head()
# Out:
#    Unnamed: 0       Ship Mode      Customer Name    Segment        Country  \
# 0           0  Standard Class      Brendan Murry  Corporate  United States
# 1           1  Standard Class      Brendan Murry  Corporate  United States
# 2           2  Standard Class      Brendan Murry  Corporate  United States
# 3           3     First Class       Lena Radford   Consumer  United States
# 4           4  Standard Class  Christine Abelman  Corporate  United States
#
#            City       State         Category Sub-Category   Sales  Quantity  \
# 0  Gaithersburg    Maryland        Furniture    Bookcases   73.94         1
# 1  Gaithersburg    Maryland        Furniture    Bookcases  173.94         3
# 2  Gaithersburg    Maryland       Technology       Phones  231.98         2
# 3   Los Angeles  California  Office Supplies      Storage  114.46         2
# 4   San Antonio       Texas       Technology  Accessories   30.08         2
#
#     Profit  Returns Payment Mode
# ...

# %%
# dropping Unnamed column
df.drop("Unnamed: 0",axis=1,inplace=True)

# %% [markdown]
# ## Exploring Relationships

# %% [markdown]
# #### task-2: to pick out variables from your data set suitable for your exploratory visual analysis (which are sales, quantity and profit columns)

# %%
#creating a subset for suitable variables
df_sub = df[['Sales', 'Quantity', 'Profit']]
df_sub
# Out:
#          Sales  Quantity   Profit
# 0       73.940         1  28.2668
# 1      173.940         3  38.2668
# 2      231.980         2  67.2742
# 3      114.460         2  28.6150
# 4       30.080         2  -5.2640
# ...        ...       ...      ...
# 5896   213.136         4  12.1176
# 5897   295.904         2   4.5188
# 5898   388.024         3  -0.6048
# 5899   462.776         3  19.7910
# 5900  2975.510         3  -0.6048
#
# [5901 rows x 3 columns]

# %% [markdown]
# #### task-3: create a correlation matrix heatmap (colored)

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(5,5))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_sub.corr(), annot = True, ax = ax)

# %% [markdown]
# ####

# %% [markdown]
# ### Correlations

# %%
# Create a correlation matrix using pandas
df.corr()
# Out:
# /var/folders/yz/w55xm0757_xf7s97jpfxx22h0000gn/T/ipykernel_63980/354464612.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              Sales  Quantity    Profit  Returns
# Sales     1.000000  0.202420  0.325915      NaN
# Quantity  0.202420  1.000000  0.074761      NaN
# Profit    0.325915  0.074761  1.000000      NaN
# Returns        NaN       NaN       NaN      NaN

# %%
# Create a correlation heatmap using matplotlib
plt.matshow(df.corr())
plt.show()
# Out:
# /var/folders/yz/w55xm0757_xf7s97jpfxx22h0000gn/T/ipykernel_63980/2907469462.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr())

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# /var/folders/yz/w55xm0757_xf7s97jpfxx22h0000gn/T/ipykernel_63980/464900279.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr(), fignum=f.number) # type of plot
# Text(0.5, 1.0, 'Correlation Matrix')
